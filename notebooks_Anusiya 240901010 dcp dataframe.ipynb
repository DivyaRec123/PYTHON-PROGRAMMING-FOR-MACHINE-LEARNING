# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original DataFrame with NaN
#          one       two     three
# a  0.047875 -0.855238  0.820942
# b       NaN       NaN       NaN
# c  1.945557 -0.724615 -1.067009
# d -0.016109 -1.665264 -2.537838
# e       NaN       NaN       NaN
# f  1.117006 -0.959763  0.564004
#
#
# Dropped DataFrame
#          one       two     three
# a  0.047875 -0.855238  0.820942
# c  1.945557 -0.724615 -1.067009
# d -0.016109 -1.665264 -2.537838
# f  1.117006 -0.959763  0.564004

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\n")
print("NaN replaced with '0'\n")
print(df.fillna(0))
# Out:
# Original DataFrame:
#          one       two     three
# a -0.270990 -2.184416  3.196510
# b       NaN       NaN       NaN
# c  2.062004 -0.009024 -0.365393
# d -1.182319 -0.407332  2.641458
# e       NaN       NaN       NaN
# f -1.165583  0.038348  1.193531
#
#
# NaN replaced with '0'
#
#         one       two     three
# a -0.270990 -2.184416  3.196510
# b  0.000000  0.000000  0.000000
# c  2.062004 -0.009024 -0.365393
# d -1.182319 -0.407332  2.641458
# e  0.000000  0.000000  0.000000
# f -1.165583  0.038348  1.193531

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original DataFrame:
#          one       two     three
# a  0.224038 -2.073104  0.116819
# b       NaN       NaN       NaN
# c -0.119722  1.705706  0.012753
# d -1.751999 -1.375330 -3.159796
# e       NaN       NaN       NaN
# f -0.173497 -0.363439  0.500251
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool
